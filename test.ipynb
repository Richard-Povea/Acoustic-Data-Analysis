# %%
import os
from pandas import read_csv, to_datetime

# %%
PATH = os.path.join(r"C:\Users\rpove\OneDrive\Escritorio\9552\Vibraciones-ada\Auto_0287\Auto_Inst",
                    "VM_001_OCT_Inst_0287_0001.rnd")

# %%
data = read_csv(PATH,
                skiprows=1, 
                parse_dates=['Start Time'],
                dayfirst=False,
                date_format="%Y-%m-%d")

# %%
data['Start Time'] = to_datetime(data['Start Time'],
                                 yearfirst=True)

# %%
data.head()
# Out:
#    Address              Start Time     X_AP  ...  Z_Over  Z_Under  Unnamed: 92
# 0        1 2024-06-24 17:27:56.500  0.00031  ...      --       UN          NaN
# 1        2 2024-06-24 17:27:56.600  0.00024  ...      --       UN          NaN
# 2        3 2024-06-24 17:27:56.700  0.00026  ...      --       UN          NaN
# 3        4 2024-06-24 17:27:56.800  0.00018  ...      --       UN          NaN
# 4        5 2024-06-24 17:27:56.900  0.00016  ...      --       UN          NaN
#
# [5 rows x 93 columns]

# %%
data.head()['Start Time'].dt.day
# Out:
# 0    24
# 1    24
# 2    24
# 3    24
# 4    24
# Name: Start Time, dtype: int32
